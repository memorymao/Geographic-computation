# %% [markdown]
# # **Assignment 2**
# ###### Further application of Python basics. Do not use existing functions in Python packages. Use the basic Python data structure and loops to do the work.

# %% [markdown]
# #### **Task 1 Read in a data file of all counties in the US.**
# ###### Make a list of unique county names.

# %%
def LoadJson():
     import requests, json
     url = "https://eric.clst.org/assets/wiki/uploads/Stuff/gz_2010_us_050_00_5m.json"

     # get the json data from the URL
     with requests.get(url) as response:
           data = response.json()
     return data

def JsonfileToData():
     data = LoadJson()
     features = data['features']
     return features


# The following part is not used to implement the tasks in the assignment
# The following part is not essential for further tasks in the assignment, just added to better understand the structure of the input data
def dataStructureAnalysis(cols, data):
    import pandas as pd
    df =  pd.DataFrame(columns = cols)
    for f in data:
          #print(f['properties']['NAME'])
          df0 = pd.DataFrame(f['properties'], index=[0])
          df = pd.concat([df[:], df0[:]])
    return df

# main procedure:
features = JsonfileToData()
cols = ['GEO_ID','STATE', 'COUNTY', 'NAME', 'LSAD', 'CENSUSAREA']
# 1. Use + to concatenate strings
print('Number of Counties in US: ' + str(len(features)))
# 2. Use format function
print('The first entry is {}'.format(features[0]['properties']['NAME']))
# 3. use f to print
print(f'The second entry is {features[1]["properties"]["NAME"]}')

#dataStructureAnalysis(cols, features)
# Out:
# Number of Counties in US: 3221
# The first entry is Valdez-Cordova
# The second entry is Wade Hampton

# %%
countries = set()
data = JsonfileToData()
for f in data:
     countries.add(f['properties']['NAME'])
print("The list of unique county names:", countries)
print("The number of unique county names:", len(countries))
# Out:
# Number of Counties in US: 3221
# The first entry is Valdez-Cordova
# The second entry is Wade Hampton
# The list of unique county names: {'Hood River', 'Colorado', 'Kosciusko', 'Aibonito', 'Griggs', 'Candler', 'Kodiak Island', 'Reeves', 'Bradley', 'Buncombe', 'Utah', 'Wibaux', 'Coffey', 'Yukon-Koyukuk', 'Taos', 'Smith', 'Fayette', 'Vanderburgh', 'Stearns', 'Martin', 'Oneida', 'Newberry', 'Shawano', 'Guernsey', 'Gentry', 'Morrison', 'Clarendon', 'Preston', 'Bowman', 'Hillsdale', 'Ohio', 'Mora', 'Hidalgo', 'Valdez-Cordova', 'De Soto', 'Broadwater', 'Ashtabula', 'West Baton Rouge', 'Caledonia', 'Washburn', 'Stafford', 'St. John the Baptist', 'Stewart', 'Coleman', 'Brazos', 'Gonzales', 'Stillwater', 'Hitchcock', 'Chicot', 'Harrison', 'Suwannee', 'Bailey', 'McCurtain', 'Piscataquis', 'Linn', 'San Saba', 'Harmon', 'Bronx', 'Desha', 'Columbus', 'Passaic', 'Boise', 'Staunton', 'Lipscomb', 'Manat�', 'Hanover', 'Big Stone', 'Walla Walla', 'Ravalli', 'Burke', 'Aguas Buenas', 'Snohomish', 'Pope', 'Colleton', 'Loudon', 'Allegany', 'Routt', 'Izard', 'Wallowa', 'Whitfield', 'Gila', 'Eddy', 'Hawkins', 'Pearl River', 'Sandusky', 'Allegan', 'Okaloosa', 'Frio', 'Lonoke', 'Ponce', 'Corozal', 'Oceana', 'Yadkin', 'Hanson', 'Osage', 'Van Wert', 'LaSalle', 'Page', 'Oktibbeha', 'Renville', 'James City
o', 'Piatt', 'Tillamook', 'Ochiltree', 'Lenoir', 'Coshocton', 'Arlington', 'Archer', 'Hamblen', 'Pierce', 'Avery', 'Newaygo', 'Goodhue', 'Ontario', 'Idaho', 'Chenango', 'Bayam�n', 'Roscommon', 'Okeechobee', 'Guaynabo', 'Stone', 'Walsh', 'Ross', 'Pitt', 'Skamania', 'Crow Wing', 'Toole', 'Cook', 'Klamath', 'McClain', 'Lajas', 'Cibola', 'Monterey', 'Randall', 'Barranquitas', 'St. Tammany', 'St. Bernard', 'Warren', 'Bacon',  ...
# The number of unique county names: 1909

# %% [markdown]
# #### **Task 2 Find the three most common names of the counties.**
# Derive the numbers of counties that use these three names, respectively. For each of them, list their county name and state code.
#
# Hint: Think about what data structure would be best for this task. Once again, do not use special functions or packages for this task. Just use basic Python data structures and loops.

# %%
def mostCommonName(k):
  featureList = JsonfileToData()
  cntyDict = {}

  for f in featureList:                             # f will be an individual feature

      name = f['properties']['NAME']               # name will be the county name

      if cntyDict.get(name) is None:               # find the name for the first time, mark it as 1
          cntyDict.update({name: 1})
      else:
          n = cntyDict.get(name)
          cntyDict.update({name: n+1})

# Once you have the dictionary cntyDict. Sort it by value.
  cntyDictSorted = sorted(cntyDict.items(), key=lambda item:item[1], reverse=True)
  return cntyDictSorted[0:k]


# main procedure: get the three most common names of countries
cnty = mostCommonName(3)
print('The most common names of the counties are {}'.format([x[0] for x in cnty]))
# Out:
# Number of Counties in US: 3221
# The first entry is Valdez-Cordova
# The second entry is Wade Hampton
# The most common names of the counties are ['Washington', 'Franklin', 'Jefferson']

# %%
# Derive the numbers of counties that use these three names, respectively. For each of them, list their county name and state code.
def commonCountries(data, k):
    cnty=mostCommonName(k)
    print('The numbers of counties that use these most common names are {}'.format(cnty))
    print(f'the top {k} most common counties along with state code.')
    print('%s  %s' % ("state","countries"))
    cnty_list=[x[0] for x in cnty]
    for f in data:
        cnty_name = f['properties']['NAME']
        if cnty_name in cnty_list:
            print('%s     %s' % (f['properties']['STATE'], cnty_name))

# main procedure: get the three most common names of countries with state code
commonCountries(data,3)
# Out:
# The numbers of counties that use these most common names are [('Washington', 31), ('Franklin', 26), ('Jefferson', 26)]
# the top 3 most common counties along with state code.
# state  countries
# 08     Washington
# 12     Washington
# 13     Franklin
# 05     Washington
# 01     Franklin
# 17     Jefferson
# 17     Washington
# 18     Franklin
# 13     Jefferson
# 16     Franklin
# 21     Franklin
# 19     Franklin
# 19     Jefferson
# 19     Washington
# 28     Franklin
# 23     Washington
# 24     Washington
# 29     Washington
# 36     Franklin
# 47     Washington
# 40     Washington
# 41     Jefferson
# 41     Washington
# 48     Franklin
# 55     Washington
# 49     Washington
# 50     Washington
# 08     Jefferson
# 05     Franklin
# 05     Jefferson
# 12     Franklin
# 12     Jefferson
# 20     Jefferson
# 20     Washington
# 21     Jefferson
# 18     Washington
# 21     Washington
# 27     Washington
# 01     Jefferson
# 13     Washington
# 22     Franklin
# 22     Jefferson
# 01     Washington
# 28     Jefferson
# 22     Washington
# 23     Franklin
# 16     Jefferson
# 16     Washington
# 25     Franklin
# 17     Franklin
# 18     Jefferson
# 20     Franklin
# 29     Franklin
# 29     Jefferson
# 47     Jefferson
# 47     Franklin
# 48     Jefferson
# 36     Jefferson
# 40     Jefferson
# 36     Washington
# 31     Franklin
# 31     Jefferson
# 30     Jefferson
# 37     Washington
# 37     Franklin
# 31     Washington
# 42     Franklin
# 39     Franklin
# 42     Jefferson
# 39     Jefferson
# 28     Washington
# 42     Washington
# 39     Washington
# 44     Washington
# 51     Franklin
# 54     Jefferson
# 51     Washington
# 51     Franklin
# 48     Washington
# 53     Franklin
# 55     Jefferson
# 53     Jefferson
# 50     Franklin

# %% [markdown]
# #### **Task 3 Basic statistics by state.**
# For each state, find
#
# The number of counties
# The name and size (census area) of the biggest and smallest county by area
# The total and average area of counties

# %%
def AreaDetailInfo():  # filter the area info for each state
    featureList = JsonfileToData()
    cntyDict = {}

    for f in featureList:                             # f will be an individual feature

        STATE = f['properties']['STATE']

        if cntyDict.get(STATE) is None:               # find the name for the first time, mark it as 1
            cntyDict[STATE]= []

        cntyDict[STATE].append([f['properties']['NAME'],f['properties']['CENSUSAREA']])

    return cntyDict


def AreaEachState(arr):    # find max/min/total/average value for each state
    total = sum([item[1] for item in arr])
    average = total/len(arr)
    cntyDictSorted = sorted(arr, key=lambda item:item[1], reverse=True)
    return cntyDictSorted[0], cntyDictSorted[-1], total, average


def AreaStatistic(cntyDict):
    maxstat = {}
    minstat = {}
    totalstat = {}
    avestat = {}
    for c in cntyDict:
      maxstat[c], minstat[c], totalstat[c], avestat[c]= AreaEachState(cntyDict[c])

    return maxstat, minstat, totalstat, avestat

def print_table(data):
    for row in data:
      #print('%s   {0:<8s}  $%.2f' % (row,data[row][0],data[row][1]))
      print(row, "   ",'{0:<24s}'.format(data[row][0]),data[row][1])



# main procedure:
cntyDict = AreaDetailInfo()
print(f'The total number of states is {len(cntyDict)}')
maxstat, minstat, totalstat, avestat = AreaStatistic(cntyDict)
print("The name and size (census area) of the biggest county by area are:")
print_table(maxstat)
print("The name and size (census area) of the smallest county by area are:")
print_table(minstat)
print("The total area of counties are:")
for row in totalstat:
  print('%s   $%.2f' % (row,totalstat[row]))
print("The average area of counties are:")
for row in avestat:
  print('%s   $%.2f' % (row,avestat[row]))
# Out:
# Number of Counties in US: 3221
# The first entry is Valdez-Cordova
# The second entry is Wade Hampton
# The total number of states is 52
# The name and size (census area) of the biggest county by area are:
# 02     Yukon-Koyukuk            145504.789
# 04     Coconino                 18618.885
# 05     Union                    1039.214
# 08     Las Animas               4772.672
# 09     Litchfield               920.56
# 12     Collier                  1998.324
# 13     Ware                     892.461
# 06     San Bernardino           20056.938
# 01     Baldwin                  1589.784
# 17     McLean                   1183.378
# 18     Allen                    657.308
# 19     Kossuth                  972.72
# 15     Hawaii                   4028.417
# 16     Idaho                    8477.352
# 20     Butler                   1429.863
# 21     Pike                     786.833
# 22     Vernon                   1327.91
# 26     Marquette                1808.401
# 27     St. Louis                6247.401
# 28     Yazoo                    922.947
# 23     Aroostook                6671.33
# 24     Frederick                660.221
# 25     Worcester                1510.77
# 30     Beaverhead               5541.624
# 41   $95988.01
# 42   $44742.70
# 48   $261231.71
# 49   $82169.62
# 53   $66455.52
# 54   $24038.21
# 55   $54157.80
# 56   $97093.14
# 72   $3423.78
# 50   $9216.66
# 51   $39490.09
# 10   $1948.54
# 11   $61.05
# 44   $1033.82
# The average area of counties are:
# 02   $19677.27
# 04   $7572.94
# 05   $693.81
# 08   $1619.40
# 09   $605.29
# 12   $800.37
# 13   $361.72
# 06   $2685.85
# 01   $755.90
# 17   $544.30
# 18   $389.41
# 19   $564.21
# 15   $1284.53
# 16   $1878.25
# 20   $778.65
# 21   $329.05
# 22   $675.06
# 26   $681.19
# 27   $915.25
# 28   $572.24
# 23   $1927.68
# 24   $404.47
# 25   $557.15
# 30   $2599.03
# 31   $826.07
# 32   $6457.72
# 33   $895.26
# 34   $350.20
# 35   $3675.70
# 29   $597.75
# 37   $486.18
# 38   $1301.90
# 39   $464.33
# 40   $890.84
# 36   $760.10
# 45   $653.49
# 46   $1148.65
# 47   $434.05
# 41   $2666.33
# 42   $667.80
# 48   $1028.47
# 49   $2833.44
# 53   $1703.99
# 54   $437.06
# 55   $752.19
# 56   $4221.44
# 72   $43.89
# 50   $658.33
# 51   $294.70
# 10   $649.51
# 11   $61.05
# 44   $206.76

# %%
# validation
cntyDict = AreaDetailInfo()
print('The state 44 is with countries:', cntyDict['44'])

maxstat, minstat, totalstat, avestat = AreaStatistic(cntyDict)
print("The name and size (census area) of the biggest county by area in state 44 is:", maxstat['44'])
print("The name and size (census area) of the smallest county by area in state 44 is:", minstat['44'])
print("The total area of counties in state 44 is:", totalstat['44'])
print("The average area of counties in state 44 is:", avestat['44'])
# Out:
# Number of Counties in US: 3221
# The first entry is Valdez-Cordova
# The second entry is Wade Hampton
# The state 44 is with countries: [['Bristol', 24.164], ['Kent', 168.528], ['Newport', 102.386], ['Providence', 409.502], ['Washington', 329.235]]
# The name and size (census area) of the biggest county by area in state 44 is: ['Providence', 409.502]
# The name and size (census area) of the smallest county by area in state 44 is: ['Bristol', 24.164]
# The total area of counties in state 44 is: 1033.815
# The average area of counties in state 44 is: 206.763

# %% [markdown]
# #### **Bonus Point**
#
# Using the JSON files for state fips and abbreviations, add state names and abbreviations to the county data above. You are also encouraged to write a new JSON file for the counties with full state name, abbreviation, and FIPS code.

# %%
statesabb = [ 'AK', 'AL', 'AR', 'AZ', 'CA', 'CO', 'CT', 'DC', 'DE', 'FL', 'GA',
           'HI', 'IA', 'ID', 'IL', 'IN', 'KS', 'KY', 'LA', 'MA', 'MD', 'ME',
           'MI', 'MN', 'MO', 'MS', 'MT', 'NC', 'ND', 'NE', 'NH', 'NJ', 'NM',
           'NV', 'NY', 'OH', 'OK', 'OR', 'PA', 'RI', 'SC', 'SD', 'TN', 'TX',
           'UT', 'VA', 'VT', 'WA', 'WI', 'WV', 'WY', 'PR']

states = {
    'AK': 'Alaska',
    'AL': 'Alabama',
    'AR': 'Arkansas',
    'AZ': 'Arizona',
    'CA': 'California',
    'CO': 'Colorado',
    'CT': 'Connecticut',
    'DC': 'District of Columbia',
    'DE': 'Delaware',
    'FL': 'Florida',
    'GA': 'Georgia',
    'HI': 'Hawaii',
    'IA': 'Iowa',
    'ID': 'Idaho',
    'IL': 'Illinois',
    'IN': 'Indiana',
    'KS': 'Kansas',
    'KY': 'Kentucky',
    'LA': 'Louisiana',
    'MA': 'Massachusetts',
    'MD': 'Maryland',
    'ME': 'Maine',
    'MI': 'Michigan',
    'MN': 'Minnesota',
    'MO': 'Missouri',
    'MS': 'Mississippi',
    'MT': 'Montana',
    'NC': 'North Carolina',
    'ND': 'North Dakota',
    'NE': 'Nebraska',
    'NH': 'New Hampshire',
    'NJ': 'New Jersey',
    'NM': 'New Mexico',
    'NV': 'Nevada',
    'NY': 'New York',
    'OH': 'Ohio',
    'OK': 'Oklahoma',
    'OR': 'Oregon',
    'PA': 'Pennsylvania',
    'RI': 'Rhode Island',
    'SC': 'South Carolina',
    'SD': 'South Dakota',
    'TN': 'Tennessee',
    'TX': 'Texas',
    'UT': 'Utah',
    'VA': 'Virginia',
    'VT': 'Vermont',
    'WA': 'Washington',
    'WI': 'Wisconsin',
    'WV': 'West Virginia',
    'WY': 'Wyoming',
    'PR': 'Puerto Rico',
    'VI': 'Virgin Islands'
}


FIPS = {
    '02':'AK', '01':'AL', '05':'AR', '04':'AZ', '06':'CA','08': 'CO',
    '09':'CT', '11':'DC', '10':'DE','12': 'FL', '13':'GA',
    '15':'HI', '19':'IA', '16':'ID', '17':'IL', '18':'IN', '20':'KS', '21':'KY',
    '22':'LA', '25':'MA', '24':'MD', '23':'ME', '26':'MI', '27':'MN', '29':'MO', '28':'MS',
    '30':'MT', '37':'NC', '38':'ND', '31':'NE', '33':'NH', '34':'NJ', '35':'NM',
    '32':'NV', '36':'NY', '39':'OH', '40':'OK', '41':'OR', '42':'PA', '44':'RI', '45':'SC',
    '46':'SD', '47':'TN', '48':'TX', '49': 'UT', '51':'VA', '50':'VT', '53':'WA','55': 'WI', '54':'WV', '56':'WY',
    '72': 'PR', '78': 'VI'
 }

# %%
def print_table2(data):
    n=7
    print('State No.',' '*n,'State Abb.',' '*n,'State Name',' '*2*n,'Country Name',' '*2*n,'Area')
    for row in data:
      print(row,' '*2*n,FIPS[row],' '*2*n,'{0:<20s}'.format(states[FIPS[row]]),'{0:<24s}'.format(data[row][0]),data[row][1])



# main procedure:   add state names and abbreviations to the county data
cntyDict = AreaDetailInfo()
print(f'The total number of states is {len(cntyDict)}')
maxstat, minstat, totalstat, avestat = AreaStatistic(cntyDict)
print("The name and size (census area) of the biggest county by area are:")
print_table2(maxstat)
print("The name and size (census area) of the smallest county by area are:")
print_table2(minstat)
print("The total area of counties are:")
print('%s     %s      %s           %s' % ('State No.','State Abb.','State Name','Area'))
for row in totalstat:
  print(row,' '*10,FIPS[row],' '*10,'{0:<20s}'.format(states[FIPS[row]]),'$%.2f' %(totalstat[row]))
print("The average area of counties are:")
print('%s     %s      %s           %s' % ('State No.','State Abb.','State Name','Area'))
for row in avestat:
  print(row, ' '*10,FIPS[row],' '*10,'{0:<20s}'.format(states[FIPS[row]]),'$%.2f' %(avestat[row]))
# Out:
# Number of Counties in US: 3221
# The first entry is Valdez-Cordova
# The second entry is Wade Hampton
# The total number of states is 52
# The name and size (census area) of the biggest county by area are:
# State No.         State Abb.         State Name                Country Name                Area
# 02                AK                Alaska               Yukon-Koyukuk            145504.789
# 47            TN            Tennessee            $41234.89
# 41            OR            Oregon               $95988.01
# 42            PA            Pennsylvania         $44742.70
# 48            TX            Texas                $261231.71
# 49            UT            Utah                 $82169.62
# 53            WA            Washington           $66455.52
# 54            WV            West Virginia        $24038.21
# 55            WI            Wisconsin            $54157.80
# 56            WY            Wyoming              $97093.14
# 72            PR            Puerto Rico          $3423.78
# 50            VT            Vermont              $9216.66
# 51            VA            Virginia             $39490.09
# 10            DE            Delaware             $1948.54
# 11            DC            District of Columbia $61.05
# 44            RI            Rhode Island         $1033.82
# The average area of counties are:
# State No.     State Abb.      State Name           Area
# 02            AK            Alaska               $19677.27
# 04            AZ            Arizona              $7572.94
# 05            AR            Arkansas             $693.81
# 08            CO            Colorado             $1619.40
# 09            CT            Connecticut          $605.29
# 12            FL            Florida              $800.37
# 13            GA            Georgia              $361.72
# 06            CA            California           $2685.85
# 01            AL            Alabama              $755.90
# 17            IL            Illinois             $544.30
# 18            IN            Indiana              $389.41
# 19            IA            Iowa                 $564.21
# 15            HI            Hawaii               $1284.53
# 16            ID            Idaho                $1878.25
# 20            KS            Kansas               $778.65
# 21            KY            Kentucky             $329.05
# 22            LA            Louisiana            $675.06
# 26            MI            Michigan             $681.19
# 27            MN            Minnesota            $915.25
# 28            MS            Mississippi          $572.24
# 23            ME            Maine                $1927.68
# 24            MD            Maryland             $404.47
# 25            MA            Massachusetts        $557.15
# 30            MT            Montana              $2599.03
# 31            NE            Nebraska             $826.07
# 32            NV            Nevada               $6457.72
# 33            NH            New Hampshire        $895.26
# 34            NJ            New Jersey           $350.20
# 35            NM            New Mexico           $3675.70
# 29            MO            Missouri             $597.75
# 37            NC            North Carolina       $486.18
# 38            ND            North Dakota         $1301.90
# 39            OH            Ohio                 $464.33
# 40            OK            Oklahoma             $890.84
# 36            NY            New York             $760.10
# 45            SC            South Carolina       $653.49
# 46            SD            South Dakota         $1148.65
# 47            TN            Tennessee            $434.05
# 41            OR            Oregon               $2666.33
# 42            PA            Pennsylvania         $667.80
# 48            TX            Texas                $1028.47
# 49            UT            Utah                 $2833.44
# 53            WA            Washington           $1703.99
# 54            WV            West Virginia        $437.06
# 55            WI            Wisconsin            $752.19
# 56            WY            Wyoming              $4221.44
# 72            PR            Puerto Rico          $43.89
# 50            VT            Vermont              $658.33
# 51            VA            Virginia             $294.70
# 10            DE            Delaware             $649.51
# 11            DC            District of Columbia $61.05
# 44            RI            Rhode Island         $206.76

# %%
def addStateName():
     data = LoadJson()
     # add state name and abbreviation
     for k in range(len(data['features'])):
           num = data["features"][k]["properties"]["STATE"]
           data["features"][k]["properties"]["STATE ABB"] = FIPS[num]
           data["features"][k]["properties"]["STATE NAME"] =states[FIPS[num]]

     return data


# main procedure:
import json
data = addStateName()
# save the result as a JSON file:
with open("sample.json", "w") as outfile:
    json.dump(data, outfile)

# %%
x= {'a':[{'b':{'c':'d','e':'f'}},{'g':{'h':'i','j':'k'}}]}

x['a'][0]['n']='m'

x
# Out:
# {'a': [{'b': {'c': 'd', 'e': 'f'}, 'n': 'm'}, {'g': {'h': 'i', 'j': 'k'}}]}
